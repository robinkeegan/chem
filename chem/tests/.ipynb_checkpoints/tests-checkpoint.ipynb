# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
os.chdir("../")

# %%
import ions

# %%
os.chdir("tests/")

# %%
major_ions = pd.read_csv("data/major_ions.csv")
major_ions = major_ions.fillna(value = 0)
major_ions.head()
# Out:
#    index collected_date Aquifer     Ca     Mg     Na     K   HCO3  CO3  \
# 0  25690     09/01/1980       N  123.0   36.3  278.0   4.8  344.0  0.0
# 1  25690     14/01/1976       N  120.0   41.0  280.0   6.0  332.0  0.0
# 2  26197     13/01/1976      Qa  136.0  163.0  845.0  10.0  464.0  0.0
# 3  26259     16/06/1976    Tomw  140.0   34.0  266.0   1.0  330.0  0.0
# 4  26364     26/08/1976    Tomw  116.0   27.0  152.0   2.0  316.0  0.0
#
#        Cl    SO4
# 0   519.0   69.0
# 1   527.0   63.0
# 2  1664.0  206.0
# 3   563.0   40.0
# 4   314.0   51.0

# %%
iso = pd.read_csv("data/isotopes.csv")
iso = iso.fillna(value = 0)
iso.head()
# Out:
#    ?DHNO collected_date Aquifer     D   O18
# 0  38805     07/05/2007      Ek -26.6 -5.34
# 1  38805     13/11/2006      Ek -28.4 -5.51
# 2  38848     31/05/2005    CP-j -28.0 -5.32
# 3  39051     04/07/2005    CP-j -29.5 -4.60
# 4  39057     23/05/2005    CP-j -29.2 -5.22

# %% [markdown]
# ### meq

# %%
meq_ions = ions.meq(major_ions.iloc[:, 3:])
meq_ions.head()
# Out:
#          Ca         Mg         Na         K      HCO3  CO3         Cl  \
# 0  6.138031   2.987040  12.092336  0.122767 -5.637792 -0.0 -14.639100
# 1  5.988323   3.373791  12.179331  0.153459 -5.441124 -0.0 -14.864751
# 2  6.786766  13.412878  36.755480  0.255766 -7.604463 -0.0 -46.935379
# 3  6.986377   2.797778  11.570364  0.025577 -5.408347 -0.0 -15.880179
# 4  5.788712   2.221765   6.611637  0.051153 -5.178902 -0.0  -8.856796
#
#         SO4
# 0 -1.436602
# 1 -1.311680
# 2 -4.288986
# 3 -0.832813
# 4 -1.061836

# %% [markdown]
# ### mM

# %%
mM_ions = ions.mM(major_ions.iloc[:, 3:])
mM_ions.head()
# Out:
#          Ca        Mg         Na         K      HCO3  CO3         Cl       SO4
# 0  3.069015  1.493520  12.092336  0.122767  5.637792  0.0  14.639100  0.718301
# 1  2.994161  1.686896  12.179331  0.153459  5.441124  0.0  14.864751  0.655840
# 2  3.393383  6.706439  36.755480  0.255766  7.604463  0.0  46.935379  2.144493
# 3  3.493188  1.398889  11.570364  0.025577  5.408347  0.0  15.880179  0.416406
# 4  2.894356  1.110883   6.611637  0.051153  5.178902  0.0   8.856796  0.530918

# %% [markdown]
# ### Schoeller

# %%
ions.schoeller(mM_ions)

# %%
ions.schoeller(mM_ions.iloc[0])

# %% [markdown]
# ### Stable Isotopes vs Chloride

# %%
ions.chloride_vs_stable_isotopes(mM_ions['Cl'].values[1:10], iso["O18"].values[1:10], iso["D"].values[1:10])

# %% [markdown]
# ### Chloride vs major ion

# %%
ions.chloride_ion_ratios(mM_ions.values)
